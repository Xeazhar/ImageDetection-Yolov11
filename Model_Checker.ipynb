# %%
#OBJECT DETECTION

from ultralytics import YOLO
import numpy as np
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from PIL import Image

# —— CONFIG ——
weights    = "runs/detect/train33/weights/best.pt"
val_root   = "Road_Damage/val"
folders    = ["potholes", "crack_issues"]
img_sub    = "images"
lbl_sub    = "labels"
iou_thresh = 0.5
out_path   = "det_confusion_matrix.png"

# —— HELPERS ——
def load_yolo_txt(label_path):
    boxes = []
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            cls = int(parts[0])
            coords = list(map(float, parts[1:5]))
            boxes.append([cls, *coords])
    return np.array(boxes)

def xywh_to_xyxy(box, img_w, img_h):
    cx, cy, w, h = box
    x1 = (cx - w/2) * img_w
    y1 = (cy - h/2) * img_h
    x2 = (cx + w/2) * img_w
    y2 = (cy + h/2) * img_h
    return [x1, y1, x2, y2]

def iou(boxA, boxB):
    xA1,yA1,xA2,yA2 = boxA
    xB1,yB1,xB2,yB2 = boxB
    xi1 = max(xA1, xB1); yi1 = max(yA1, yB1)
    xi2 = min(xA2, xB2); yi2 = min(yA2, yB2)
    inter = max(0, xi2-xi1) * max(0, yi2-yi1)
    areaA = (xA2-xA1)*(yA2-yA1)
    areaB = (xB2-xB1)*(yB2-yB1)
    union = areaA + areaB - inter
    return inter/union if union > 0 else 0

# —— LOAD MODEL & NAMES ——
model = YOLO(weights)
names = model.names             # e.g. {0:"crack_issues",1:"potholes"}
class_idx_list = sorted(names.keys())

# —— MATCH & COLLECT ——
y_true, y_pred = [], []

for folder in folders:
    img_dir = os.path.join(val_root, folder, img_sub)
    lbl_dir = os.path.join(val_root, folder, lbl_sub)
    for img_file in os.listdir(img_dir):
        if not img_file.lower().endswith((".jpg", ".jpeg", ".png")):
            continue

        img_path = os.path.join(img_dir, img_file)
        lbl_path = os.path.join(lbl_dir, img_file.rsplit(".",1)[0] + ".txt")
        if not os.path.isfile(lbl_path):
            continue

        # Load and convert GT boxes
        gt = load_yolo_txt(lbl_path)
        w, h = Image.open(img_path).size
        gt_boxes = []
        for cls, x, y, wd, hd in gt:
            xyxy = xywh_to_xyxy([x, y, wd, hd], w, h)
            gt_boxes.append([int(cls), *xyxy])
        gt_boxes = np.array(gt_boxes)

        # Run detection
        res = model(img_path, imgsz=640)[0]
        preds_xyxy = res.boxes.xyxy.cpu().numpy()
        preds_cls  = res.boxes.cls.cpu().numpy().astype(int)

        matched_gt = set()
        # Greedy match preds → GT
        for pi, pred_box in enumerate(preds_xyxy):
            best_iou = 0.0
            best_gi  = -1
            for gi, gt_box in enumerate(gt_boxes):
                if gi in matched_gt:
                    continue
                i = iou(pred_box, gt_box[1:])
                if i > best_iou:
                    best_iou, best_gi = i, gi
            if best_iou >= iou_thresh and best_gi >= 0:
                y_true.append(int(gt_boxes[best_gi, 0]))
                y_pred.append(int(preds_cls[pi]))
                matched_gt.add(best_gi)

# —— BUILD & SAVE CONFUSION MATRIX ——
cm   = confusion_matrix(y_true, y_pred, labels=class_idx_list)
disp = ConfusionMatrixDisplay(cm, display_labels=[names[i] for i in class_idx_list])

fig, ax = plt.subplots(figsize=(7, 6))
disp.plot(ax=ax, cmap="Blues", xticks_rotation="vertical")
plt.title("Detection Confusion Matrix (IoU ≥ 0.5)")
plt.tight_layout()
plt.savefig(out_path, dpi=150)
plt.close(fig)

print(f"Saved detection confusion matrix to {out_path}")
# Out:
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Chuck HolePunch Out (6).jpg: 640x640 2 potholess, 10.0ms
# Speed: 3.9ms preprocess, 10.0ms inference, 91.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Chuck-holePunch-out (RL).jpg: 640x640 2 potholess, 20.7ms
# Speed: 2.6ms preprocess, 20.7ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Patholes.jpg: 640x640 (no detections), 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - pothole (4).jpg: 640x640 2 potholess, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Pothole Bowl-shaped (LL).jpg: 640x640 1 potholes, 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - POTHOLES (1).jpg: 640x640 1 potholes, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Potholes 13.jpg: 640x640 1 potholes, 19.0ms
# Speed: 1.6ms preprocess, 19.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01- Potholes (Bowl-Shaped) (LL).jpg: 640x640 1 potholes, 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01- Potholes2.jpg: 640x640 1 potholes, 7.2ms
# Speed: 1.9ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\1 - Potholes.jpg: 640x640 1 potholes, 13.6ms
# Speed: 1.8ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\Pothole(1).jpg: 640x640 1 potholes, 20.9ms
# Speed: 1.9ms preprocess, 20.9ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Block Crack.jpg: 640x640 (no detections), 19.1ms
# Speed: 1.9ms preprocess, 19.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Cracks (Longitudinal Cracks) (RL)8.jpg: 640x640 (no detections), 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Cracks (Longitudinal Craks) (RL)8.jpg: 640x640 (no detections), 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Longitudinal Cracks 5 and scaling.jpg: 640x640 (no detections), 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (1).jpg: 640x640 (no detections), 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (Longitudinal Crack) (LL).jpg: 640x640 (no detections), 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (Longitudinal Crack) (RL)2.jpg: 640x640 2 crack_issuess, 11.3ms
# Speed: 2.2ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks Traversal2.jpg: 640x640 1 crack_issues, 18.2ms
# Speed: 2.1ms preprocess, 18.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks(1).jpg: 640x640 (no detections), 11.6ms
# Speed: 2.9ms preprocess, 11.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks.jpg: 640x640 (no detections), 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks4.jpg: 640x640 1 crack_issues, 11.2ms
# Speed: 1.8ms preprocess, 11.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Reflection Crack (CL).jpg: 640x640 (no detections), 13.5ms
# Speed: 2.4ms preprocess, 13.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\Longitudinal Crack (RL).jpg: 640x640 2 crack_issuess, 22.7ms
# Speed: 2.0ms preprocess, 22.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\Longitudinal Crack.jpg: 640x640 2 crack_issuess, 12.7ms
# Speed: 2.3ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\Transverse crack.jpg: 640x640 1 crack_issues, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Saved detection confusion matrix to det_confusion_matrix.png

# %%
#CLASSIFICATION

from ultralytics import YOLO
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os

# 1. Reload your trained weights
weights = "runs/classify/train17/weights/best.pt"
model   = YOLO(weights)

# 2. Grab the model's own names dict
#    e.g. {0: "crack_issues", 1: "potholes"}
names = model.names  

# 3. Validation root and your folder names
val_root = "Road_Damage/val"
folders  = ["potholes", "crack_issues"]  # whatever sub-folders you have

# 4. Invert names → index for easy lookup
name_to_idx = {v: k for k, v in names.items()}

y_true, y_pred = [], []

for folder in folders:
    true_idx = name_to_idx[folder]
    img_dir  = os.path.join(val_root, folder, "images")
    for img in os.listdir(img_dir):
        if not img.lower().endswith((".jpg", ".jpeg", ".png")):
            continue
        path = os.path.join(img_dir, img)
        y_true.append(true_idx)
        res = model(path, imgsz=640)[0]
        y_pred.append(int(res.probs.top1))

# 5. Print classification report
print("\n📊 Classification Report:")
print(classification_report(
    y_true, 
    y_pred, 
    target_names=[names[i] for i in sorted(name_to_idx.values())],
    zero_division=0
))

# 5. Build & save the confusion matrix
cm   = confusion_matrix(y_true, y_pred, labels=sorted(name_to_idx.values()))
disp = ConfusionMatrixDisplay(cm,
       display_labels=[names[i] for i in sorted(name_to_idx.values())])

fig, ax = plt.subplots(figsize=(7,6))
disp.plot(ax=ax, cmap="Blues", xticks_rotation="vertical")
plt.title("Validation Confusion Matrix")
plt.tight_layout()

# **Save** to file instead of (or as well as) plt.show()
out_path = "confusion_matrix.png"
plt.savefig(out_path, dpi=150)
print(f"Saved confusion matrix to {out_path}")
plt.close(fig)
