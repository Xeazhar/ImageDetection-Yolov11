# %%
#OBJECT DETECTION

from ultralytics import YOLO
import numpy as np
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from PIL import Image

# —— CONFIG ——
weights    = "runs/detect/train35/weights/best.pt"
val_root   = "Road_Damage/val"
folders    = ["potholes", "crack_issues", "alligator_crack_issues", "ravelling", "pumping_and_depression", "open_manhole"] 
img_sub    = "images"
lbl_sub    = "labels"
iou_thresh = 0.5
out_path   = "det_confusion_matrix.png"

# —— HELPERS ——
def load_yolo_txt(label_path):
    boxes = []
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            cls = int(parts[0])
            coords = list(map(float, parts[1:5]))
            boxes.append([cls, *coords])
    return np.array(boxes)

def xywh_to_xyxy(box, img_w, img_h):
    cx, cy, w, h = box
    x1 = (cx - w/2) * img_w
    y1 = (cy - h/2) * img_h
    x2 = (cx + w/2) * img_w
    y2 = (cy + h/2) * img_h
    return [x1, y1, x2, y2]

def iou(boxA, boxB):
    xA1,yA1,xA2,yA2 = boxA
    xB1,yB1,xB2,yB2 = boxB
    xi1 = max(xA1, xB1); yi1 = max(yA1, yB1)
    xi2 = min(xA2, xB2); yi2 = min(yA2, yB2)
    inter = max(0, xi2-xi1) * max(0, yi2-yi1)
    areaA = (xA2-xA1)*(yA2-yA1)
    areaB = (xB2-xB1)*(yB2-yB1)
    union = areaA + areaB - inter
    return inter/union if union > 0 else 0

# —— LOAD MODEL & NAMES ——
model = YOLO(weights)
names = model.names             # e.g. {0:"crack_issues",1:"potholes"}
class_idx_list = sorted(names.keys())

# —— MATCH & COLLECT ——
y_true, y_pred = [], []

for folder in folders:
    img_dir = os.path.join(val_root, folder, img_sub)
    lbl_dir = os.path.join(val_root, folder, lbl_sub)
    for img_file in os.listdir(img_dir):
        if not img_file.lower().endswith((".jpg", ".jpeg", ".png")):
            continue

        img_path = os.path.join(img_dir, img_file)
        lbl_path = os.path.join(lbl_dir, img_file.rsplit(".",1)[0] + ".txt")
        if not os.path.isfile(lbl_path):
            continue

        # Load and convert GT boxes
        gt = load_yolo_txt(lbl_path)
        w, h = Image.open(img_path).size
        gt_boxes = []
        for cls, x, y, wd, hd in gt:
            xyxy = xywh_to_xyxy([x, y, wd, hd], w, h)
            gt_boxes.append([int(cls), *xyxy])
        gt_boxes = np.array(gt_boxes)

        # Run detection
        res = model(img_path, imgsz=640)[0]
        preds_xyxy = res.boxes.xyxy.cpu().numpy()
        preds_cls  = res.boxes.cls.cpu().numpy().astype(int)

        matched_gt = set()
        # Greedy match preds → GT
        for pi, pred_box in enumerate(preds_xyxy):
            best_iou = 0.0
            best_gi  = -1
            for gi, gt_box in enumerate(gt_boxes):
                if gi in matched_gt:
                    continue
                i = iou(pred_box, gt_box[1:])
                if i > best_iou:
                    best_iou, best_gi = i, gi
            if best_iou >= iou_thresh and best_gi >= 0:
                y_true.append(int(gt_boxes[best_gi, 0]))
                y_pred.append(int(preds_cls[pi]))
                matched_gt.add(best_gi)

# —— BUILD & SAVE CONFUSION MATRIX ——
cm   = confusion_matrix(y_true, y_pred, labels=class_idx_list)
disp = ConfusionMatrixDisplay(cm, display_labels=[names[i] for i in class_idx_list])

fig, ax = plt.subplots(figsize=(7, 6))
disp.plot(ax=ax, cmap="Blues", xticks_rotation="vertical")
plt.title("Detection Confusion Matrix (IoU ≥ 0.5)")
plt.tight_layout()
plt.savefig(out_path, dpi=150)
plt.close(fig)

print(f"Saved detection confusion matrix to {out_path}")
# Out:
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Chuck HolePunch Out (6).jpg: 640x640 2 potholess, 24.1ms
# Speed: 4.3ms preprocess, 24.1ms inference, 131.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Chuck-holePunch-out (RL).jpg: 640x640 3 potholess, 74.0ms
# Speed: 8.4ms preprocess, 74.0ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Patholes.jpg: 640x640 2 potholess, 12.5ms
# Speed: 2.3ms preprocess, 12.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - pothole (4).jpg: 640x640 1 potholes, 23.5ms
# Speed: 2.3ms preprocess, 23.5ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Pothole Bowl-shaped (LL).jpg: 640x640 1 potholes, 21.7ms
# Speed: 2.2ms preprocess, 21.7ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - POTHOLES (1).jpg: 640x640 1 potholes, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Potholes 13.jpg: 640x640 1 potholes, 12.5ms
# Speed: 1.7ms preprocess, 12.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01- Potholes (Bowl-Shaped) (LL).jpg: 640x640 2 potholess, 14.6ms
# Speed: 2.6ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01- Potholes2.jpg: 640x640 1 potholes, 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\1 - Potholes.jpg: 640x640 1 potholes, 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\Pothole(1).jpg: 640x640 1 potholes, 11.5ms
# Speed: 2.7ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Block Crack.jpg: 640x640 2 crack_issuess, 24.7ms
# Speed: 3.1ms preprocess, 24.7ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Cracks (Longitudinal Cracks) (RL)8.jpg: 640x640 (no detections), 24.1ms
# Speed: 2.4ms preprocess, 24.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Cracks (Longitudinal Craks) (RL)8.jpg: 640x640 (no detections), 23.2ms
# Speed: 2.8ms preprocess, 23.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Longitudinal Cracks 5 and scaling.jpg: 640x640 (no detections), 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (1).jpg: 640x640 2 crack_issuess, 20.2ms
# Speed: 1.7ms preprocess, 20.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (Longitudinal Crack) (LL).jpg: 640x640 (no detections), 26.8ms
# Speed: 2.4ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (Longitudinal Crack) (RL)2.jpg: 640x640 1 crack_issues, 23.7ms
# Speed: 2.3ms preprocess, 23.7ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks Traversal2.jpg: 640x640 1 crack_issues, 21.4ms
# Speed: 2.3ms preprocess, 21.4ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks(1).jpg: 640x640 2 crack_issuess, 12.3ms
# Speed: 2.4ms preprocess, 12.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks.jpg: 640x640 2 crack_issuess, 15.0ms
# Speed: 1.6ms preprocess, 15.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks4.jpg: 640x640 1 crack_issues, 12.2ms
# Speed: 3.2ms preprocess, 12.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Reflection Crack (CL).jpg: 640x640 2 crack_issuess, 13.0ms
# Speed: 2.5ms preprocess, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\Longitudinal Crack (RL).jpg: 640x640 2 crack_issuess, 17.2ms
# Speed: 1.8ms preprocess, 17.2ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\Longitudinal Crack.jpg: 640x640 1 crack_issues, 13.4ms
# Speed: 2.9ms preprocess, 13.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\Transverse crack.jpg: 640x640 (no detections), 12.9ms
# Speed: 2.3ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\12 - Cracks10.jpg: 640x640 1 alligator_crack_issues, 11.1ms
# Speed: 2.8ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack1.jpg: 640x640 3 crack_issuess, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack100.jpg: 640x640 1 alligator_crack_issues, 12.1ms
# Speed: 2.2ms preprocess, 12.1ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack106.jpg: 640x640 2 alligator_crack_issuess, 13.6ms
# Speed: 2.6ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack65.jpg: 640x640 1 ravelling, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack77.jpg: 640x640 1 ravelling, 21.2ms
# Speed: 2.2ms preprocess, 21.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack81.jpg: 640x640 1 alligator_crack_issues, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack92.jpg: 640x640 2 alligator_crack_issuess, 12.1ms
# Speed: 2.9ms preprocess, 12.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack98.jpg: 640x640 1 alligator_crack_issues, 14.0ms
# Speed: 2.2ms preprocess, 14.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\alligator 8.jpg: 640x640 1 alligator_crack_issues, 24.5ms
# Speed: 2.7ms preprocess, 24.5ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\Alligator crack(1).jpg: 640x640 2 alligator_crack_issuess, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\alligator6(1).jpg: 640x640 2 ravellings, 12.1ms
# Speed: 2.3ms preprocess, 12.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\pothole with ravelling.jpg: 640x640 2 ravellings, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling and pothole 3.jpg: 640x640 2 ravellings, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling and pothole1.jpg: 640x640 (no detections), 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling22.jpg: 640x640 (no detections), 11.7ms
# Speed: 2.4ms preprocess, 11.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling3.jpg: 640x640 (no detections), 24.9ms
# Speed: 3.1ms preprocess, 24.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling8(1).jpg: 640x640 (no detections), 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression with alligator.jpg: 640x640 1 alligator_crack_issues, 11.5ms
# Speed: 2.6ms preprocess, 11.5ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(12).jpg: 640x640 (no detections), 10.7ms
# Speed: 2.2ms preprocess, 10.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(13).jpg: 640x640 1 potholes, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(15).jpg: 640x640 1 ravelling, 11.8ms
# Speed: 2.2ms preprocess, 11.8ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(2).jpg: 640x640 1 potholes, 11.0ms
# Speed: 1.8ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(24).jpg: 640x640 1 alligator_crack_issues, 22.1ms
# Speed: 2.4ms preprocess, 22.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression..jpg: 640x640 (no detections), 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\10 - Depressed Manhole (Cepmo).jpg: 640x640 1 potholes, 23.2ms
# Speed: 2.3ms preprocess, 23.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\10 - Depressed Manhole Cover.jpg: 640x640 (no detections), 22.5ms
# Speed: 3.2ms preprocess, 22.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1004.jpg: 640x640 1 alligator_crack_issues, 1 open_manhole, 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1024.jpg: 640x640 2 open_manholes, 24.0ms
# Speed: 2.5ms preprocess, 24.0ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1031.jpg: 640x640 1 potholes, 1 open_manhole, 13.9ms
# Speed: 3.1ms preprocess, 13.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1039.jpg: 640x640 1 open_manhole, 11.6ms
# Speed: 1.9ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1063.jpg: 640x640 1 open_manhole, 12.9ms
# Speed: 2.7ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1105.jpg: 640x640 1 open_manhole, 18.4ms
# Speed: 2.5ms preprocess, 18.4ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1125.jpg: 640x640 1 open_manhole, 12.4ms
# Speed: 2.2ms preprocess, 12.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1131.jpg: 640x640 1 open_manhole, 12.5ms
# Speed: 1.9ms preprocess, 12.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1140.jpg: 640x640 1 open_manhole, 16.3ms
# Speed: 2.8ms preprocess, 16.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
# Saved detection confusion matrix to det_confusion_matrix.png

# %%
#CLASSIFICATION

from ultralytics import YOLO
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os

# 1. Reload your trained weights
weights = "runs/classify/train20/weights/best.pt"
model   = YOLO(weights)

# 2. Grab the model's own names dict
#    e.g. {0: "crack_issues", 1: "potholes"}
names = model.names  

# 3. Validation root and your folder names
val_root = "Road_Damage/val"
folders  = ["potholes", "crack_issues", "alligator_crack_issues", "ravelling", "pumping_and_depression", "open_manhole"]  # whatever sub-folders you have

# 4. Invert names → index for easy lookup
name_to_idx = {v: k for k, v in names.items()}

y_true, y_pred = [], []

for folder in folders:
    true_idx = name_to_idx[folder]
    img_dir  = os.path.join(val_root, folder, "images")
    for img in os.listdir(img_dir):
        if not img.lower().endswith((".jpg", ".jpeg", ".png")):
            continue
        path = os.path.join(img_dir, img)
        y_true.append(true_idx)
        res = model(path, imgsz=640)[0]
        y_pred.append(int(res.probs.top1))

# 5. Print classification report
print("\n📊 Classification Report:")
print(classification_report(
    y_true, 
    y_pred, 
    target_names=[names[i] for i in sorted(name_to_idx.values())],
    zero_division=0
))

# 5. Build & save the confusion matrix
cm   = confusion_matrix(y_true, y_pred, labels=sorted(name_to_idx.values()))
disp = ConfusionMatrixDisplay(cm,
       display_labels=[names[i] for i in sorted(name_to_idx.values())])

fig, ax = plt.subplots(figsize=(7,6))
disp.plot(ax=ax, cmap="Blues", xticks_rotation="vertical")
plt.title("Validation Confusion Matrix")
plt.tight_layout()

# **Save** to file instead of (or as well as) plt.show()
out_path = "confusion_matrix.png"
plt.savefig(out_path, dpi=150)
print(f"Saved confusion matrix to {out_path}")
plt.close(fig)
# Out:
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Chuck HolePunch Out (6).jpg: 640x640 potholes 1.00, crack_issues 0.00, open_manhole 0.00, pumping_and_depression 0.00, alligator_crack_issues 0.00, 7.4ms
# Speed: 6.3ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Chuck-holePunch-out (RL).jpg: 640x640 potholes 1.00, crack_issues 0.00, pumping_and_depression 0.00, open_manhole 0.00, ravelling 0.00, 11.1ms
# Speed: 7.4ms preprocess, 11.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Patholes.jpg: 640x640 ravelling 0.95, crack_issues 0.03, pumping_and_depression 0.02, potholes 0.01, alligator_crack_issues 0.00, 5.7ms
# Speed: 7.1ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - pothole (4).jpg: 640x640 potholes 0.96, crack_issues 0.04, pumping_and_depression 0.00, ravelling 0.00, open_manhole 0.00, 4.2ms
# Speed: 7.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Pothole Bowl-shaped (LL).jpg: 640x640 potholes 1.00, ravelling 0.00, pumping_and_depression 0.00, alligator_crack_issues 0.00, crack_issues 0.00, 5.0ms
# Speed: 6.9ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - POTHOLES (1).jpg: 640x640 potholes 1.00, ravelling 0.00, crack_issues 0.00, open_manhole 0.00, alligator_crack_issues 0.00, 11.5ms
# Speed: 8.1ms preprocess, 11.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Potholes 13.jpg: 640x640 crack_issues 0.80, potholes 0.19, open_manhole 0.00, pumping_and_depression 0.00, alligator_crack_issues 0.00, 7.0ms
# Speed: 7.1ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01- Potholes (Bowl-Shaped) (LL).jpg: 640x640 crack_issues 0.98, potholes 0.02, pumping_and_depression 0.00, alligator_crack_issues 0.00, open_manhole 0.00, 5.9ms
# Speed: 6.5ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01- Potholes2.jpg: 640x640 potholes 0.81, crack_issues 0.19, open_manhole 0.00, ravelling 0.00, pumping_and_depression 0.00, 7.0ms
# Speed: 8.0ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\1 - Potholes.jpg: 640x640 potholes 1.00, crack_issues 0.00, open_manhole 0.00, pumping_and_depression 0.00, ravelling 0.00, 5.1ms
# Speed: 8.7ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\Pothole(1).jpg: 640x640 crack_issues 0.94, potholes 0.06, open_manhole 0.00, ravelling 0.00, pumping_and_depression 0.00, 5.7ms
# Speed: 8.4ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Block Crack.jpg: 640x640 crack_issues 1.00, potholes 0.00, alligator_crack_issues 0.00, open_manhole 0.00, ravelling 0.00, 10.6ms
# Speed: 6.2ms preprocess, 10.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Cracks (Longitudinal Cracks) (RL)8.jpg: 640x640 crack_issues 0.99, potholes 0.01, ravelling 0.00, open_manhole 0.00, pumping_and_depression 0.00, 6.0ms
# Speed: 7.1ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Cracks (Longitudinal Craks) (RL)8.jpg: 640x640 crack_issues 0.97, potholes 0.02, ravelling 0.00, pumping_and_depression 0.00, alligator_crack_issues 0.00, 7.5ms
# Speed: 6.5ms preprocess, 7.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Longitudinal Cracks 5 and scaling.jpg: 640x640 crack_issues 0.99, potholes 0.01, open_manhole 0.00, ravelling 0.00, alligator_crack_issues 0.00, 4.6ms
# Speed: 7.9ms preprocess, 4.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (1).jpg: 640x640 crack_issues 1.00, potholes 0.00, pumping_and_depression 0.00, open_manhole 0.00, ravelling 0.00, 10.5ms
# Speed: 7.4ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (Longitudinal Crack) (LL).jpg: 640x640 crack_issues 1.00, potholes 0.00, pumping_and_depression 0.00, alligator_crack_issues 0.00, open_manhole 0.00, 7.9ms
# Speed: 7.7ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (Longitudinal Crack) (RL)2.jpg: 640x640 crack_issues 0.96, potholes 0.04, open_manhole 0.00, pumping_and_depression 0.00, alligator_crack_issues 0.00, 6.7ms
# Speed: 7.5ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks Traversal2.jpg: 640x640 crack_issues 0.85, potholes 0.10, pumping_and_depression 0.04, open_manhole 0.01, alligator_crack_issues 0.00, 5.7ms
# Speed: 7.6ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks(1).jpg: 640x640 crack_issues 0.90, potholes 0.10, ravelling 0.00, open_manhole 0.00, pumping_and_depression 0.00, 5.2ms
# Speed: 7.7ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks.jpg: 640x640 crack_issues 0.97, potholes 0.03, ravelling 0.00, open_manhole 0.00, pumping_and_depression 0.00, 5.9ms
# Speed: 7.0ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks4.jpg: 640x640 crack_issues 1.00, potholes 0.00, pumping_and_depression 0.00, ravelling 0.00, open_manhole 0.00, 6.8ms
# Speed: 6.5ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Reflection Crack (CL).jpg: 640x640 crack_issues 0.92, potholes 0.08, ravelling 0.00, pumping_and_depression 0.00, open_manhole 0.00, 6.9ms
# Speed: 6.5ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\Longitudinal Crack (RL).jpg: 640x640 crack_issues 1.00, potholes 0.00, ravelling 0.00, alligator_crack_issues 0.00, pumping_and_depression 0.00, 5.2ms
# Speed: 8.0ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\Longitudinal Crack.jpg: 640x640 crack_issues 1.00, potholes 0.00, alligator_crack_issues 0.00, ravelling 0.00, pumping_and_depression 0.00, 10.0ms
# Speed: 7.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\Transverse crack.jpg: 640x640 crack_issues 1.00, open_manhole 0.00, potholes 0.00, ravelling 0.00, pumping_and_depression 0.00, 10.7ms
# Speed: 8.0ms preprocess, 10.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\12 - Cracks10.jpg: 640x640 alligator_crack_issues 0.97, ravelling 0.03, crack_issues 0.01, potholes 0.00, open_manhole 0.00, 6.2ms
# Speed: 7.5ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack1.jpg: 640x640 alligator_crack_issues 0.95, crack_issues 0.05, ravelling 0.00, potholes 0.00, open_manhole 0.00, 6.3ms
# Speed: 8.8ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack100.jpg: 640x640 alligator_crack_issues 0.83, ravelling 0.12, crack_issues 0.05, open_manhole 0.00, potholes 0.00, 5.0ms
# Speed: 6.9ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack106.jpg: 640x640 alligator_crack_issues 0.97, ravelling 0.02, crack_issues 0.01, potholes 0.00, open_manhole 0.00, 4.6ms
# Speed: 7.1ms preprocess, 4.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack65.jpg: 640x640 alligator_crack_issues 0.83, ravelling 0.16, pumping_and_depression 0.00, open_manhole 0.00, crack_issues 0.00, 11.1ms
# Speed: 8.0ms preprocess, 11.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack77.jpg: 640x640 ravelling 0.99, alligator_crack_issues 0.01, pumping_and_depression 0.00, crack_issues 0.00, open_manhole 0.00, 12.0ms
# Speed: 7.4ms preprocess, 12.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack81.jpg: 640x640 alligator_crack_issues 0.66, ravelling 0.31, pumping_and_depression 0.03, open_manhole 0.00, crack_issues 0.00, 10.6ms
# Speed: 6.9ms preprocess, 10.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack92.jpg: 640x640 alligator_crack_issues 1.00, ravelling 0.00, pumping_and_depression 0.00, open_manhole 0.00, crack_issues 0.00, 7.6ms
# Speed: 6.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack98.jpg: 640x640 alligator_crack_issues 0.78, ravelling 0.20, pumping_and_depression 0.03, crack_issues 0.00, potholes 0.00, 9.4ms
# Speed: 6.4ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\alligator 8.jpg: 640x640 alligator_crack_issues 0.91, ravelling 0.08, pumping_and_depression 0.01, crack_issues 0.00, open_manhole 0.00, 11.8ms
# Speed: 8.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\Alligator crack(1).jpg: 640x640 alligator_crack_issues 0.61, ravelling 0.38, pumping_and_depression 0.01, crack_issues 0.00, open_manhole 0.00, 8.9ms
# Speed: 8.1ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\alligator6(1).jpg: 640x640 alligator_crack_issues 0.57, pumping_and_depression 0.22, ravelling 0.20, crack_issues 0.00, open_manhole 0.00, 5.6ms
# Speed: 8.1ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\pothole with ravelling.jpg: 640x640 ravelling 1.00, pumping_and_depression 0.00, alligator_crack_issues 0.00, potholes 0.00, open_manhole 0.00, 11.9ms
# Speed: 6.6ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling and pothole 3.jpg: 640x640 ravelling 0.97, crack_issues 0.03, pumping_and_depression 0.00, alligator_crack_issues 0.00, potholes 0.00, 8.8ms
# Speed: 7.4ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling and pothole1.jpg: 640x640 ravelling 1.00, alligator_crack_issues 0.00, pumping_and_depression 0.00, open_manhole 0.00, crack_issues 0.00, 4.7ms
# Speed: 6.1ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling22.jpg: 640x640 ravelling 0.97, alligator_crack_issues 0.02, pumping_and_depression 0.01, crack_issues 0.00, potholes 0.00, 12.0ms
# Speed: 8.7ms preprocess, 12.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling3.jpg: 640x640 ravelling 1.00, alligator_crack_issues 0.00, pumping_and_depression 0.00, crack_issues 0.00, open_manhole 0.00, 12.3ms
# Speed: 7.6ms preprocess, 12.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling8(1).jpg: 640x640 ravelling 0.99, alligator_crack_issues 0.00, pumping_and_depression 0.00, open_manhole 0.00, crack_issues 0.00, 6.7ms
# Speed: 7.9ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression with alligator.jpg: 640x640 alligator_crack_issues 0.96, crack_issues 0.03, ravelling 0.00, potholes 0.00, pumping_and_depression 0.00, 7.9ms
# Speed: 7.2ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(12).jpg: 640x640 pumping_and_depression 1.00, alligator_crack_issues 0.00, crack_issues 0.00, open_manhole 0.00, potholes 0.00, 5.5ms
# Speed: 7.0ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(13).jpg: 640x640 pumping_and_depression 0.99, alligator_crack_issues 0.00, potholes 0.00, crack_issues 0.00, ravelling 0.00, 5.3ms
# Speed: 7.0ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(15).jpg: 640x640 ravelling 1.00, pumping_and_depression 0.00, alligator_crack_issues 0.00, crack_issues 0.00, open_manhole 0.00, 5.3ms
# Speed: 5.5ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(2).jpg: 640x640 pumping_and_depression 1.00, potholes 0.00, crack_issues 0.00, alligator_crack_issues 0.00, open_manhole 0.00, 7.2ms
# Speed: 7.2ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(24).jpg: 640x640 ravelling 0.71, alligator_crack_issues 0.25, crack_issues 0.04, open_manhole 0.00, pumping_and_depression 0.00, 6.9ms
# Speed: 7.7ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression..jpg: 640x640 pumping_and_depression 1.00, alligator_crack_issues 0.00, crack_issues 0.00, open_manhole 0.00, ravelling 0.00, 5.1ms
# Speed: 5.6ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\10 - Depressed Manhole (Cepmo).jpg: 640x640 potholes 0.82, pumping_and_depression 0.16, crack_issues 0.01, open_manhole 0.01, ravelling 0.00, 9.7ms
# Speed: 6.8ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\10 - Depressed Manhole Cover.jpg: 640x640 crack_issues 0.97, pumping_and_depression 0.02, potholes 0.01, open_manhole 0.00, alligator_crack_issues 0.00, 3.6ms
# Speed: 5.4ms preprocess, 3.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1004.jpg: 640x640 open_manhole 1.00, crack_issues 0.00, ravelling 0.00, pumping_and_depression 0.00, alligator_crack_issues 0.00, 5.1ms
# Speed: 6.8ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1024.jpg: 640x640 ravelling 0.67, open_manhole 0.33, pumping_and_depression 0.00, alligator_crack_issues 0.00, crack_issues 0.00, 9.1ms
# Speed: 7.5ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1031.jpg: 640x640 open_manhole 0.66, potholes 0.23, pumping_and_depression 0.10, crack_issues 0.00, ravelling 0.00, 6.6ms
# Speed: 8.9ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1039.jpg: 640x640 open_manhole 0.76, potholes 0.24, crack_issues 0.00, ravelling 0.00, pumping_and_depression 0.00, 10.7ms
# Speed: 7.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1063.jpg: 640x640 open_manhole 0.90, pumping_and_depression 0.09, alligator_crack_issues 0.01, crack_issues 0.00, potholes 0.00, 10.6ms
# Speed: 7.5ms preprocess, 10.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1105.jpg: 640x640 open_manhole 0.93, crack_issues 0.04, ravelling 0.02, potholes 0.00, alligator_crack_issues 0.00, 8.1ms
# Speed: 6.5ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1125.jpg: 640x640 open_manhole 1.00, potholes 0.00, crack_issues 0.00, pumping_and_depression 0.00, alligator_crack_issues 0.00, 3.7ms
# Speed: 6.1ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1131.jpg: 640x640 open_manhole 1.00, crack_issues 0.00, pumping_and_depression 0.00, potholes 0.00, alligator_crack_issues 0.00, 5.7ms
# Speed: 6.8ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1140.jpg: 640x640 open_manhole 1.00, crack_issues 0.00, pumping_and_depression 0.00, potholes 0.00, alligator_crack_issues 0.00, 8.9ms
# Speed: 7.9ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 📊 Classification Report:
#                         precision    recall  f1-score   support
#
# alligator_crack_issues       0.92      0.92      0.92        12
#           crack_issues       0.79      1.00      0.88        15
#           open_manhole       1.00      0.73      0.84        11
#               potholes       0.88      0.64      0.74        11
# pumping_and_depression       1.00      0.57      0.73         7
#              ravelling       0.55      1.00      0.71         6
#
#               accuracy                           0.82        62
#              macro avg       0.85      0.81      0.80        62
#           weighted avg       0.87      0.82      0.82        62
#
# Saved confusion matrix to confusion_matrix.png
