# %%
#OBJECT DETECTION

from ultralytics import YOLO
import numpy as np
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from PIL import Image

# —— CONFIG ——
weights    = "runs/detect/train33/weights/best.pt"
val_root   = "Road_Damage/val"
folders    = ["potholes", "crack_issues"]
img_sub    = "images"
lbl_sub    = "labels"
iou_thresh = 0.5
out_path   = "det_confusion_matrix.png"

# —— HELPERS ——
def load_yolo_txt(label_path):
    boxes = []
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            cls = int(parts[0])
            coords = list(map(float, parts[1:5]))
            boxes.append([cls, *coords])
    return np.array(boxes)

def xywh_to_xyxy(box, img_w, img_h):
    cx, cy, w, h = box
    x1 = (cx - w/2) * img_w
    y1 = (cy - h/2) * img_h
    x2 = (cx + w/2) * img_w
    y2 = (cy + h/2) * img_h
    return [x1, y1, x2, y2]

def iou(boxA, boxB):
    xA1,yA1,xA2,yA2 = boxA
    xB1,yB1,xB2,yB2 = boxB
    xi1 = max(xA1, xB1); yi1 = max(yA1, yB1)
    xi2 = min(xA2, xB2); yi2 = min(yA2, yB2)
    inter = max(0, xi2-xi1) * max(0, yi2-yi1)
    areaA = (xA2-xA1)*(yA2-yA1)
    areaB = (xB2-xB1)*(yB2-yB1)
    union = areaA + areaB - inter
    return inter/union if union > 0 else 0

# —— LOAD MODEL & NAMES ——
model = YOLO(weights)
names = model.names             # e.g. {0:"crack_issues",1:"potholes"}
class_idx_list = sorted(names.keys())

# —— MATCH & COLLECT ——
y_true, y_pred = [], []

for folder in folders:
    img_dir = os.path.join(val_root, folder, img_sub)
    lbl_dir = os.path.join(val_root, folder, lbl_sub)
    for img_file in os.listdir(img_dir):
        if not img_file.lower().endswith((".jpg", ".jpeg", ".png")):
            continue

        img_path = os.path.join(img_dir, img_file)
        lbl_path = os.path.join(lbl_dir, img_file.rsplit(".",1)[0] + ".txt")
        if not os.path.isfile(lbl_path):
            continue

        # Load and convert GT boxes
        gt = load_yolo_txt(lbl_path)
        w, h = Image.open(img_path).size
        gt_boxes = []
        for cls, x, y, wd, hd in gt:
            xyxy = xywh_to_xyxy([x, y, wd, hd], w, h)
            gt_boxes.append([int(cls), *xyxy])
        gt_boxes = np.array(gt_boxes)

        # Run detection
        res = model(img_path, imgsz=640)[0]
        preds_xyxy = res.boxes.xyxy.cpu().numpy()
        preds_cls  = res.boxes.cls.cpu().numpy().astype(int)

        matched_gt = set()
        # Greedy match preds → GT
        for pi, pred_box in enumerate(preds_xyxy):
            best_iou = 0.0
            best_gi  = -1
            for gi, gt_box in enumerate(gt_boxes):
                if gi in matched_gt:
                    continue
                i = iou(pred_box, gt_box[1:])
                if i > best_iou:
                    best_iou, best_gi = i, gi
            if best_iou >= iou_thresh and best_gi >= 0:
                y_true.append(int(gt_boxes[best_gi, 0]))
                y_pred.append(int(preds_cls[pi]))
                matched_gt.add(best_gi)

# —— BUILD & SAVE CONFUSION MATRIX ——
cm   = confusion_matrix(y_true, y_pred, labels=class_idx_list)
disp = ConfusionMatrixDisplay(cm, display_labels=[names[i] for i in class_idx_list])

fig, ax = plt.subplots(figsize=(7, 6))
disp.plot(ax=ax, cmap="Blues", xticks_rotation="vertical")
plt.title("Detection Confusion Matrix (IoU ≥ 0.5)")
plt.tight_layout()
plt.savefig(out_path, dpi=150)
plt.close(fig)

print(f"Saved detection confusion matrix to {out_path}")
# Out:
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Chuck-holePunch-out (RL).jpg: 640x640 potholes 1.00, open_manhole 0.00, alligator_crack_issues 0.00, pumping_and_depression 0.00, crack_issues 0.00, 4.9ms
# Speed: 13.7ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 80
#      78 # Run detection
#      79 res = model(img_path, imgsz=640)[0]
# ---> 80 preds_xyxy = res.boxes.xyxy.cpu().numpy()
#      81 preds_cls  = res.boxes.cls.cpu().numpy().astype(int)
#      83 matched_gt = set()
#
# AttributeError: 'NoneType' object has no attribute 'xyxy'

# %%
#CLASSIFICATION

from ultralytics import YOLO
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os

# 1. Reload your trained weights
weights = "runs/classify/train19/weights/best.pt"
model   = YOLO(weights)

# 2. Grab the model's own names dict
#    e.g. {0: "crack_issues", 1: "potholes"}
names = model.names  

# 3. Validation root and your folder names
val_root = "Road_Damage/val"
folders  = ["potholes", "crack_issues", "alligator_crack_issues", "ravelling", "pumping_and_depression", "open_manhole"]  # whatever sub-folders you have

# 4. Invert names → index for easy lookup
name_to_idx = {v: k for k, v in names.items()}

y_true, y_pred = [], []

for folder in folders:
    true_idx = name_to_idx[folder]
    img_dir  = os.path.join(val_root, folder, "images")
    for img in os.listdir(img_dir):
        if not img.lower().endswith((".jpg", ".jpeg", ".png")):
            continue
        path = os.path.join(img_dir, img)
        y_true.append(true_idx)
        res = model(path, imgsz=640)[0]
        y_pred.append(int(res.probs.top1))

# 5. Print classification report
print("\n📊 Classification Report:")
print(classification_report(
    y_true, 
    y_pred, 
    target_names=[names[i] for i in sorted(name_to_idx.values())],
    zero_division=0
))

# 5. Build & save the confusion matrix
cm   = confusion_matrix(y_true, y_pred, labels=sorted(name_to_idx.values()))
disp = ConfusionMatrixDisplay(cm,
       display_labels=[names[i] for i in sorted(name_to_idx.values())])

fig, ax = plt.subplots(figsize=(7,6))
disp.plot(ax=ax, cmap="Blues", xticks_rotation="vertical")
plt.title("Validation Confusion Matrix")
plt.tight_layout()

# **Save** to file instead of (or as well as) plt.show()
out_path = "confusion_matrix.png"
plt.savefig(out_path, dpi=150)
print(f"Saved confusion matrix to {out_path}")
plt.close(fig)
# Out:
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Chuck-holePunch-out (RL).jpg: 640x640 potholes 1.00, open_manhole 0.00, alligator_crack_issues 0.00, pumping_and_depression 0.00, crack_issues 0.00, 17.7ms
# Speed: 12.4ms preprocess, 17.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Patholes.jpg: 640x640 ravelling 0.98, alligator_crack_issues 0.01, potholes 0.01, crack_issues 0.00, open_manhole 0.00, 45.9ms
# Speed: 11.5ms preprocess, 45.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Pothole Bowl-shaped (LL).jpg: 640x640 potholes 1.00, ravelling 0.00, open_manhole 0.00, alligator_crack_issues 0.00, pumping_and_depression 0.00, 59.5ms
# Speed: 14.5ms preprocess, 59.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01 - Potholes 13.jpg: 640x640 potholes 0.77, ravelling 0.22, open_manhole 0.00, crack_issues 0.00, alligator_crack_issues 0.00, 37.2ms
# Speed: 8.6ms preprocess, 37.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01- Potholes (Bowl-Shaped) (LL).jpg: 640x640 potholes 0.99, crack_issues 0.01, open_manhole 0.00, alligator_crack_issues 0.00, ravelling 0.00, 5.2ms
# Speed: 8.0ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\01- Potholes2.jpg: 640x640 potholes 0.75, crack_issues 0.18, ravelling 0.07, open_manhole 0.00, alligator_crack_issues 0.00, 4.2ms
# Speed: 6.5ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\1 - Potholes.jpg: 640x640 potholes 0.71, crack_issues 0.29, open_manhole 0.00, ravelling 0.00, pumping_and_depression 0.00, 6.4ms
# Speed: 5.5ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\potholes\images\Pothole(1).jpg: 640x640 potholes 0.75, crack_issues 0.19, ravelling 0.03, alligator_crack_issues 0.02, open_manhole 0.02, 5.5ms
# Speed: 6.0ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Block Crack.jpg: 640x640 open_manhole 0.51, ravelling 0.27, crack_issues 0.18, alligator_crack_issues 0.04, potholes 0.00, 5.6ms
# Speed: 6.3ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Cracks (Longitudinal Cracks) (RL)8.jpg: 640x640 crack_issues 0.99, potholes 0.01, alligator_crack_issues 0.00, ravelling 0.00, open_manhole 0.00, 6.3ms
# Speed: 5.3ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Cracks (Longitudinal Craks) (RL)8.jpg: 640x640 crack_issues 0.99, potholes 0.01, ravelling 0.00, alligator_crack_issues 0.00, open_manhole 0.00, 5.7ms
# Speed: 6.0ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12 - Longitudinal Cracks 5 and scaling.jpg: 640x640 crack_issues 0.96, open_manhole 0.02, alligator_crack_issues 0.01, potholes 0.01, ravelling 0.00, 5.2ms
# Speed: 5.6ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (1).jpg: 640x640 crack_issues 1.00, potholes 0.00, open_manhole 0.00, alligator_crack_issues 0.00, ravelling 0.00, 6.1ms
# Speed: 5.2ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (Longitudinal Crack) (LL).jpg: 640x640 crack_issues 0.85, potholes 0.13, open_manhole 0.02, alligator_crack_issues 0.00, ravelling 0.00, 6.6ms
# Speed: 6.5ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks (Longitudinal Crack) (RL)2.jpg: 640x640 crack_issues 0.50, potholes 0.49, open_manhole 0.00, alligator_crack_issues 0.00, ravelling 0.00, 5.2ms
# Speed: 5.3ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Cracks.jpg: 640x640 crack_issues 1.00, potholes 0.00, alligator_crack_issues 0.00, open_manhole 0.00, pumping_and_depression 0.00, 6.0ms
# Speed: 5.6ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\12- Reflection Crack (CL).jpg: 640x640 potholes 0.89, crack_issues 0.09, ravelling 0.01, open_manhole 0.00, alligator_crack_issues 0.00, 4.6ms
# Speed: 5.6ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\Longitudinal Crack.jpg: 640x640 crack_issues 0.99, potholes 0.01, alligator_crack_issues 0.00, ravelling 0.00, open_manhole 0.00, 5.1ms
# Speed: 5.8ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\crack_issues\images\Transverse crack.jpg: 640x640 crack_issues 0.99, open_manhole 0.00, alligator_crack_issues 0.00, potholes 0.00, ravelling 0.00, 8.2ms
# Speed: 5.3ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\12 - Cracks(1).jpg: 640x640 alligator_crack_issues 0.88, potholes 0.06, crack_issues 0.04, open_manhole 0.01, ravelling 0.00, 7.4ms
# Speed: 5.9ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\12 - Cracks9.jpg: 640x640 alligator_crack_issues 0.91, ravelling 0.08, crack_issues 0.01, open_manhole 0.00, potholes 0.00, 8.1ms
# Speed: 5.7ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack105.jpg: 640x640 alligator_crack_issues 1.00, ravelling 0.00, crack_issues 0.00, open_manhole 0.00, potholes 0.00, 9.4ms
# Speed: 5.3ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack25.jpg: 640x640 alligator_crack_issues 1.00, ravelling 0.00, open_manhole 0.00, pumping_and_depression 0.00, crack_issues 0.00, 5.3ms
# Speed: 6.6ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack3.jpg: 640x640 alligator_crack_issues 0.97, crack_issues 0.03, ravelling 0.00, open_manhole 0.00, potholes 0.00, 6.0ms
# Speed: 6.1ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack31.jpg: 640x640 alligator_crack_issues 1.00, pumping_and_depression 0.00, open_manhole 0.00, ravelling 0.00, potholes 0.00, 7.9ms
# Speed: 6.4ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack33.jpg: 640x640 alligator_crack_issues 1.00, potholes 0.00, open_manhole 0.00, pumping_and_depression 0.00, crack_issues 0.00, 7.6ms
# Speed: 6.4ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack55.jpg: 640x640 alligator_crack_issues 1.00, ravelling 0.00, open_manhole 0.00, pumping_and_depression 0.00, crack_issues 0.00, 8.1ms
# Speed: 6.3ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack56.jpg: 640x640 alligator_crack_issues 0.82, ravelling 0.16, open_manhole 0.01, pumping_and_depression 0.00, potholes 0.00, 6.2ms
# Speed: 6.1ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack59.jpg: 640x640 alligator_crack_issues 0.58, open_manhole 0.38, ravelling 0.03, pumping_and_depression 0.00, potholes 0.00, 5.8ms
# Speed: 5.2ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack65.jpg: 640x640 ravelling 0.79, alligator_crack_issues 0.20, pumping_and_depression 0.00, open_manhole 0.00, potholes 0.00, 6.7ms
# Speed: 5.5ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack72.jpg: 640x640 alligator_crack_issues 1.00, ravelling 0.00, potholes 0.00, pumping_and_depression 0.00, open_manhole 0.00, 8.4ms
# Speed: 7.5ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack76.jpg: 640x640 alligator_crack_issues 0.98, ravelling 0.02, open_manhole 0.00, pumping_and_depression 0.00, crack_issues 0.00, 7.7ms
# Speed: 6.2ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack78.jpg: 640x640 alligator_crack_issues 1.00, ravelling 0.00, open_manhole 0.00, pumping_and_depression 0.00, potholes 0.00, 7.7ms
# Speed: 6.7ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack84.jpg: 640x640 alligator_crack_issues 1.00, pumping_and_depression 0.00, open_manhole 0.00, ravelling 0.00, crack_issues 0.00, 4.2ms
# Speed: 5.6ms preprocess, 4.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack9.jpg: 640x640 ravelling 0.82, alligator_crack_issues 0.18, open_manhole 0.00, crack_issues 0.00, potholes 0.00, 8.7ms
# Speed: 6.6ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\2 - Alligator Crack91.jpg: 640x640 alligator_crack_issues 0.97, open_manhole 0.02, pumping_and_depression 0.01, ravelling 0.00, potholes 0.00, 4.8ms
# Speed: 6.5ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\alligator 8(1).jpg: 640x640 alligator_crack_issues 1.00, open_manhole 0.00, pumping_and_depression 0.00, ravelling 0.00, potholes 0.00, 7.8ms
# Speed: 6.7ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\alligator crack 4.jpg: 640x640 alligator_crack_issues 0.96, pumping_and_depression 0.03, open_manhole 0.01, ravelling 0.00, potholes 0.00, 8.9ms
# Speed: 6.2ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\Alligator crack.jpg: 640x640 ravelling 0.99, alligator_crack_issues 0.01, pumping_and_depression 0.00, open_manhole 0.00, crack_issues 0.00, 7.8ms
# Speed: 5.4ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\alligator.jpg: 640x640 alligator_crack_issues 1.00, pumping_and_depression 0.00, potholes 0.00, ravelling 0.00, open_manhole 0.00, 8.9ms
# Speed: 6.0ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\alligator4.jpg: 640x640 alligator_crack_issues 0.95, pumping_and_depression 0.03, ravelling 0.02, open_manhole 0.00, potholes 0.00, 8.1ms
# Speed: 5.8ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\alligator5.jpg: 640x640 ravelling 0.92, crack_issues 0.04, alligator_crack_issues 0.03, open_manhole 0.00, pumping_and_depression 0.00, 7.4ms
# Speed: 5.9ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\alligator_crack_issues\images\alligator6(1).jpg: 640x640 alligator_crack_issues 0.93, ravelling 0.04, pumping_and_depression 0.04, open_manhole 0.00, crack_issues 0.00, 7.4ms
# Speed: 5.7ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\pothole with ravelling.jpg: 640x640 ravelling 1.00, open_manhole 0.00, alligator_crack_issues 0.00, potholes 0.00, crack_issues 0.00, 6.9ms
# Speed: 5.1ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling and pothole 3.jpg: 640x640 ravelling 1.00, alligator_crack_issues 0.00, open_manhole 0.00, crack_issues 0.00, pumping_and_depression 0.00, 7.3ms
# Speed: 5.7ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling and pothole1.jpg: 640x640 ravelling 1.00, alligator_crack_issues 0.00, open_manhole 0.00, crack_issues 0.00, potholes 0.00, 6.4ms
# Speed: 6.0ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling22.jpg: 640x640 ravelling 0.61, alligator_crack_issues 0.39, pumping_and_depression 0.00, open_manhole 0.00, potholes 0.00, 7.2ms
# Speed: 4.9ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling3.jpg: 640x640 ravelling 1.00, alligator_crack_issues 0.00, crack_issues 0.00, open_manhole 0.00, potholes 0.00, 7.5ms
# Speed: 5.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\ravelling\images\ravelling8(1).jpg: 640x640 ravelling 1.00, alligator_crack_issues 0.00, open_manhole 0.00, crack_issues 0.00, potholes 0.00, 6.0ms
# Speed: 5.8ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression with alligator.jpg: 640x640 ravelling 0.41, alligator_crack_issues 0.38, pumping_and_depression 0.18, open_manhole 0.02, crack_issues 0.01, 7.2ms
# Speed: 6.1ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(12).jpg: 640x640 pumping_and_depression 0.98, alligator_crack_issues 0.02, open_manhole 0.00, potholes 0.00, crack_issues 0.00, 6.0ms
# Speed: 6.7ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(13).jpg: 640x640 pumping_and_depression 0.91, alligator_crack_issues 0.09, potholes 0.00, open_manhole 0.00, crack_issues 0.00, 7.0ms
# Speed: 5.8ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(15).jpg: 640x640 ravelling 0.97, alligator_crack_issues 0.03, pumping_and_depression 0.00, crack_issues 0.00, open_manhole 0.00, 7.9ms
# Speed: 6.3ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(2).jpg: 640x640 pumping_and_depression 1.00, alligator_crack_issues 0.00, open_manhole 0.00, potholes 0.00, crack_issues 0.00, 6.9ms
# Speed: 6.3ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression(24).jpg: 640x640 alligator_crack_issues 0.86, ravelling 0.13, open_manhole 0.01, crack_issues 0.00, pumping_and_depression 0.00, 7.5ms
# Speed: 5.1ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\pumping_and_depression\images\05-Pumping and Depression..jpg: 640x640 pumping_and_depression 0.83, alligator_crack_issues 0.15, open_manhole 0.02, potholes 0.00, crack_issues 0.00, 8.1ms
# Speed: 5.4ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\10 - Depressed Manhole (Cepmo).jpg: 640x640 open_manhole 0.57, pumping_and_depression 0.34, potholes 0.06, alligator_crack_issues 0.03, ravelling 0.00, 7.7ms
# Speed: 6.8ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\10 - Depressed Manhole Cover.jpg: 640x640 pumping_and_depression 0.58, open_manhole 0.23, crack_issues 0.11, alligator_crack_issues 0.08, potholes 0.00, 5.2ms
# Speed: 6.3ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1004.jpg: 640x640 open_manhole 1.00, alligator_crack_issues 0.00, potholes 0.00, crack_issues 0.00, ravelling 0.00, 6.8ms
# Speed: 6.6ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1024.jpg: 640x640 open_manhole 0.87, ravelling 0.13, alligator_crack_issues 0.00, crack_issues 0.00, pumping_and_depression 0.00, 7.4ms
# Speed: 5.5ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1031.jpg: 640x640 open_manhole 0.93, potholes 0.07, ravelling 0.00, crack_issues 0.00, pumping_and_depression 0.00, 8.9ms
# Speed: 6.5ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1039.jpg: 640x640 open_manhole 0.93, potholes 0.06, ravelling 0.01, crack_issues 0.00, alligator_crack_issues 0.00, 9.5ms
# Speed: 5.6ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1063.jpg: 640x640 open_manhole 1.00, potholes 0.00, alligator_crack_issues 0.00, pumping_and_depression 0.00, crack_issues 0.00, 7.6ms
# Speed: 6.6ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1105.jpg: 640x640 open_manhole 0.97, ravelling 0.02, potholes 0.00, alligator_crack_issues 0.00, crack_issues 0.00, 6.3ms
# Speed: 5.5ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1125.jpg: 640x640 open_manhole 1.00, potholes 0.00, alligator_crack_issues 0.00, ravelling 0.00, pumping_and_depression 0.00, 6.5ms
# Speed: 5.1ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1131.jpg: 640x640 open_manhole 1.00, alligator_crack_issues 0.00, potholes 0.00, pumping_and_depression 0.00, crack_issues 0.00, 8.5ms
# Speed: 6.7ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jazzb\ImageDetection-Yolov9\Road_Damage\val\open_manhole\images\1140.jpg: 640x640 open_manhole 1.00, alligator_crack_issues 0.00, potholes 0.00, crack_issues 0.00, ravelling 0.00, 8.3ms
# Speed: 6.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 📊 Classification Report:
#                         precision    recall  f1-score   support
#
# alligator_crack_issues       0.95      0.83      0.89        24
#           crack_issues       1.00      0.82      0.90        11
#           open_manhole       0.91      0.91      0.91        11
#               potholes       0.88      0.88      0.88         8
# pumping_and_depression       0.80      0.57      0.67         7
#              ravelling       0.46      1.00      0.63         6
#
#               accuracy                           0.84        67
#              macro avg       0.83      0.83      0.81        67
#           weighted avg       0.88      0.84      0.85        67
#
# Saved confusion matrix to confusion_matrix.png
